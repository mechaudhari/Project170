# %%
pwd
# Out:
# 'C:\\Users\\mchaud1\\OneDrive - IL State University\\IT170\\ClassProject'

# %%
.git

# %%
# !git add .

# %%
for i,line in enumerate(open("Ubiquitination","r")):
    line = line.strip()
    if i == 0:
        continue
    parts = line.split("\t")
    protein_id = parts[1]
    num = parts[2]
    pos = []
    for i in pos:
        pos.append(num)

# %%
from collections import defaultdict

with open("Unique_protein.txt","r") as f:
    ids = f.readlines()
    for i,line in enumerate(open("Ubiquitination","r")):
        line = line.strip()
        if i == 0:
            continue
        parts = line.split("\t")
        protein_id = parts[1]
        position = parts[2]

        #pos = []
        #for i in pos:
            
        d = defaultdict(list)

        for ids[len(parts)] in protein_id:
            d[ids[len(protein_id)]].append(parts)
print(d)

# %%
for i,line in enumerate(open("Acetylation","r")):
    line = line.strip()
    if i == 0:
        continue
    parts = line.split("\t")
    protien_id = parts[1]
    unique_number = parts[2]
